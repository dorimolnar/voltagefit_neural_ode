# %% [markdown]
# This notebook contains training a neural network for additional current with which we try to match the recording from a single-compartment ACTIVE model to our real, experimental data.
#
# Here we use the normalized voltage and the us as input to the neural network (time is not included!). We define u in a differential equation.
#
# We initialize the NN based on https://arxiv.org/pdf/2311.15890, and with it we get stable u values.
#
# For the best results we use two separate NNs for the spiking and non-spiking regions.
#
# After the first training (dtw loss with some spike-height punishment) we choose the best 40 models to fine-tune (sse loss).

# %%
import os
os.environ['XLA_FLAGS'] = '--xla_cpu_use_thunk_runtime=false'
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = "0.95"

# %load_ext autoreload
# %autoreload 2



from jax import config
config.update("jax_enable_x64", True)


import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import numpy as np
import pickle
import optax
import jaxley as jx

import jax.random as jr
from typing import List


import equinox as eqx
import flax.nnx as nnx

# %% [markdown]
# Let's see the data!

# %%
t_max = 80.0
cut = 1500  # We cut the first 1500 datapoints because this period contains no stimulus

setup = "488683425"
# setup = "485574832"
# setup = "480353286"
# setup = "473601979"



# Define target
from voltage_fitting.build_simulator import (
    get_experimental_data
)

t, v_data, i_amp = get_experimental_data(setup, cut, t_max)
v_data = jnp.asarray(v_data[None,])
# Out:
# dt_difference 5.0
# Amplitude stimulus: 0.20999999344348907

# %%
plt.plot(v_data[0])

# %%
# Define the single-compartment cell to train
from voltage_fitting.single_build_simulator import (
    setup_simulator,
    setup_simulator_step,
    build_cell,
    set_setup,
    get_bounds,
    transform_uniform_to_normal,
    get_prior
)

seed = 0

rng_key = jax.random.PRNGKey(seed)

all_setup = set_setup(setup)
cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup["length"])
simulate_single = setup_simulator(cell, cut, t_max, all_setup["v_init"], i_amp)


# Sampling parameters
_, lower, upper = get_bounds()

transform_params, inv_transform_params = transform_uniform_to_normal(lower, upper)
sample_prior = get_prior(lower, upper, transform_params)

init_rng_key, sampling_rng_key = jax.random.split(rng_key)

# Sample 1 initialization randomly.
sampled_params = sample_prior(init_rng_key)
inv_sampled_params = inv_transform_params(sampled_params)

v_single = simulate_single(inv_sampled_params, v_data[0])[0]
# Out:
# Added 1 external_states. See `.externals` for details.
# Added 1 recordings. See `.recordings` for details.
# Number of parameters: 15

# %%
plt.plot(v_single[0])

# %% [markdown]
# **How do 100000 simulations of single-compartment cells with random parameters look like? Are there spikes at all? Are they too high?**

# %%
from voltage_fitting.loss_util import (
    get_scaled_loss,
)


n_params = 100_000
opt_params = jax.vmap(sample_prior)(
    jax.random.split(init_rng_key, n_params)
)

def predict(params):
    inv_params = inv_transform_params(params)
    simulate_single = setup_simulator(cell, cut, t_max, all_setup["v_init"], i_amp)
    v = simulate_single(inv_params, v_data[0])[0]
    return get_scaled_loss(v_data[0], v[0], 1.0, 0.05), jnp.abs(jnp.max(v[0])-10.0)

cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup["length"])
losses, diffs = jax.vmap(predict)(opt_params)
# Out:
# Added 1 external_states. See `.externals` for details.
# Added 1 recordings. See `.recordings` for details.

# %%
print('Minimum loss: ', np.min(losses), ', index: ', np.argmin(losses))
print('Minimum height diff: ', np.min(diffs), ', index: ',np.argmin(diffs))
print(f'There are {jnp.sum(diffs < 30)} spiking simulations.')
# Out:
# Minimum loss:  16.26498944798083 , index:  4151
# Minimum height diff:  0.0027496782037630396 , index:  16035
# There are 9825 spiking simulations.

# %%
cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup["length"])
inv_params = inv_transform_params(opt_params[np.argmin(losses)])
    
simulate_single = setup_simulator(cell, cut, t_max, all_setup["v_init"], i_amp)
v = simulate_single(inv_params, v_data[0])[0]


fig, axs = plt.subplots(1,2, figsize = (15,5))

axs[0].plot(v_data[0])
axs[0].plot(v[0], linestyle='--')
axs[0].set_title("Best loss")

cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup["length"])
inv_params = inv_transform_params(opt_params[np.argmin(diffs)])
    
simulate_single = setup_simulator(cell, cut, t_max, all_setup["v_init"], i_amp)
v = simulate_single(inv_params, v_data[0])[0]

axs[1].plot(v_data[0])
axs[1].plot(v[0], linestyle='--')
axs[1].set_title("Best height")
# Out:
# Added 1 external_states. See `.externals` for details.
# Added 1 recordings. See `.recordings` for details.
# Added 1 external_states. See `.externals` for details.
# Added 1 recordings. See `.recordings` for details.
# Text(0.5, 1.0, 'Best height')

# %% [markdown]
# **Initialization of the NNs**

# %%
from voltage_fitting.initialization import (
    rejection_sample_eigenvalues,
    generate_all_lambda_matrices,
    generate_all_pi_matrices,
    generate_W_matrices,
)

key = jax.random.PRNGKey(0)
dt = 0.025
u_dimension = 8

eigs = rejection_sample_eigenvalues(
    key = key,
    solver_order=1,   
    h=dt,
    u_dim=u_dimension,
    use_complex=True
)

print("Sampled Eigenvalues:")
for e in eigs:
    print(e, ", scaled with dt: ", dt*e)
# Out:
# Sampled Eigenvalues:
# (-42.141613528976286-22.98417698424073j) , scaled with dt:  (-1.0535403382244073-0.5746044246060182j)
# (-42.141613528976286+22.98417698424073j) , scaled with dt:  (-1.0535403382244073+0.5746044246060182j)
# (-8.516035334431441+15.86861961008248j) , scaled with dt:  (-0.21290088336078605+0.396715490252062j)
# (-8.516035334431441-15.86861961008248j) , scaled with dt:  (-0.21290088336078605-0.396715490252062j)
# (-21.545506252691013-34.14736393037374j) , scaled with dt:  (-0.5386376563172753-0.8536840982593437j)
# (-21.545506252691013+34.14736393037374j) , scaled with dt:  (-0.5386376563172753+0.8536840982593437j)
# (-36.88311383073451-19.00424583475928j) , scaled with dt:  (-0.9220778457683627-0.47510614586898203j)
# (-36.88311383073451+19.00424583475928j) , scaled with dt:  (-0.9220778457683627+0.47510614586898203j)

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot scaled eigenvalues for each h
scaled_eigs = dt*eigs
ax.plot(scaled_eigs.real, scaled_eigs.imag, 'o', label=f"Step size = {dt}")

# Plot Euler's method stability region: circle centered at -1 with radius 1
theta = np.linspace(-np.pi, np.pi, 100)
x = -1 + np.cos(theta)
y = np.sin(theta)
ax.plot(x, y, color='lightgrey', label='Euler Stability Region')

ax.set_xlim(-0.5, 0.5)
ax.set_ylim(-0.2, 0.2)

ax.axhline(0, color='black', linestyle='--', linewidth=0.5)
ax.axvline(0, color='black', linestyle='--', linewidth=0.5)
ax.set_title("Scaled Eigenvalues and Forward Euler Stability Region")
ax.set_xlabel("Real Part")
ax.set_ylabel("Imaginary Part")
ax.legend()
ax.grid(True)
plt.axis('equal')
plt.show()

# %% [markdown]
# Now we make the Lambda, Pi and W matrices based on the paper

# %%
num_layers = 3
layer_shapes = [(u_dimension + 1, 32), (32, 16), (16, u_dimension)]

lambda_matrices = generate_all_lambda_matrices(layer_shapes, eigs, num_layers)

pi_matrices = generate_all_pi_matrices(key, layer_shapes)

W_matrices = generate_W_matrices(lambda_matrices, pi_matrices)

# %%
# Checking the eigenvalues of the generated initialization
jnp.linalg.eigvals(W_matrices[2]@W_matrices[1]@W_matrices[0][:, :u_dimension])
# Out:
# Array([-42.14161353+22.98417698j, -42.14161353-22.98417698j,
#        -21.54550625+34.14736393j, -21.54550625-34.14736393j,
#        -36.88311383+19.00424583j, -36.88311383-19.00424583j,
#         -8.51603533+15.86861961j,  -8.51603533-15.86861961j],      dtype=complex128)

# %% [markdown]
# **Define the NNs**

# %%
# Possible normalization functions
@jax.jit
def normalize_voltage(v):
    # Normalize voltage between -1 and 1
    return 2 * (v - jnp.min(v_data)) / (jnp.max(v_data) - jnp.min(v_data)) - 1

@jax.jit
def softsign_transform(v):
    return v / (1 + jnp.abs(v))

@jax.jit
def tempered_tanh(v, scale=0.05):
    return jnp.tanh(scale * v)

# %%
class SimpleNeuralNet(eqx.Module):
    linear1: eqx.nn.Linear
    linear2: eqx.nn.Linear
    linear3: eqx.nn.Linear

    def __init__(self, *, key, u_dimension=8, W_matrices: List[jax.Array], epsilon: float = 1e-4):
        k1, k2, k3, k_b1, k_b2, k_b3 = jr.split(key, 6)

        self.linear1 = eqx.nn.Linear(u_dimension + 1, 32, key=k1)
        self.linear2 = eqx.nn.Linear(32, 16, key=k2)
        self.linear3 = eqx.nn.Linear(16, u_dimension, key=k3)


        self.linear1 = eqx.tree_at(lambda l: l.weight, self.linear1, W_matrices[0])
        self.linear2 = eqx.tree_at(lambda l: l.weight, self.linear2, W_matrices[1])
        self.linear3 = eqx.tree_at(lambda l: l.weight, self.linear3, W_matrices[2])

        self.linear1 = eqx.tree_at(
            lambda l: l.bias, self.linear1,
            jr.uniform(k_b1, (32,), minval=-epsilon, maxval=epsilon)
        )
        self.linear2 = eqx.tree_at(
            lambda l: l.bias, self.linear2,
            jr.uniform(k_b2, (16,), minval=-epsilon, maxval=epsilon)
        )
        self.linear3 = eqx.tree_at(
            lambda l: l.bias, self.linear3,
            jr.uniform(k_b3, (u_dimension,), minval=-epsilon, maxval=epsilon)
        )

    def __call__(self, x):
        x = jax.nn.relu(self.linear1(x))
        x = jax.nn.relu(self.linear2(x))
        return self.linear3(x)


class ReadoutNet(eqx.Module):
    linear1: eqx.nn.Linear
    linear2: eqx.nn.Linear

    def __init__(self, *, key, u_dimension=8):
        k1, k2 = jr.split(key, 2)
        self.linear1 = eqx.nn.Linear(u_dimension, 32, key=k1)
        self.linear2 = eqx.nn.Linear(32, 1, key=k2)

    def __call__(self, u):
        x = jax.nn.relu(self.linear1(u))
        return self.linear2(x)


class CorrectionModel(eqx.Module):
    neural_net: SimpleNeuralNet
    readout_net: ReadoutNet
    channel_params_normal: jax.Array

    def __init__(self, *, key, init_params, u_dimension=8, W_matrices: List[jax.Array], epsilon: float = 1e-4):
        k1, k2 = jr.split(key, 2)
        self.neural_net = SimpleNeuralNet(key=k1, u_dimension=u_dimension, W_matrices=W_matrices, epsilon=epsilon)
        self.readout_net = ReadoutNet(key=k2, u_dimension=u_dimension)
        self.channel_params_normal = init_params

    def __call__(self, u, v):
        u_new = self.neural_net(u, v)
        return self.readout_net(u_new)
    
class DoubleCorrectionModel(eqx.Module):
    spike_neural_net: eqx.Module
    spike_readout_net: eqx.Module
    nospike_neural_net: eqx.Module
    nospike_readout_net: eqx.Module
    channel_params_normal: jnp.ndarray

    def __init__(self, *, key, init_params, u_dimension=8, W_matrices: List[jax.Array], epsilon: float = 1e-4):
        k1, k2, k3, k4 = jr.split(key, 4)
        self.spike_neural_net = SimpleNeuralNet(key=k1, u_dimension=u_dimension, W_matrices=W_matrices, epsilon=epsilon)
        self.spike_readout_net = ReadoutNet(key=k2, u_dimension=u_dimension)
        self.nospike_neural_net = SimpleNeuralNet(key=k3, u_dimension=u_dimension, W_matrices=W_matrices, epsilon=epsilon)
        self.nospike_readout_net = ReadoutNet(key=k4, u_dimension=u_dimension)
        self.channel_params_normal = init_params

    def __call__(self, u, v):
        u_new = self.neural_net(u, v)
        return self.readout_net(u_new)

# %% [markdown]
# **Define the simulation and the loss**

# %%
dt = 0.025
dv_treshold = 0.5


def simulate_full_trace(spike_neural_net, spike_readout_net, nospike_neural_net, nospike_readout_net, initial_state, step_fn, current, time_vec, u_init, x_o, added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr = None):
    def cond_fn(carry):
        t, _, _, _, diff, _ = carry
        keep_running = t < len(time_vec)
    
        if thr is None:
            return keep_running
        else:
            return jnp.logical_and(keep_running, diff < thr)

    def body_fn(carry):
        t, state, u, recs_adds, diff, prev_voltage = carry

        voltage = state["v"].squeeze()
        voltage_normalized = normalize_voltage(voltage)
        #voltage_normalized = softsign_transform(voltage)
        #voltage_normalized = tempered_tanh(voltage)


        inputs = jnp.concatenate([u, jnp.expand_dims(voltage_normalized, 0)], axis=0)

        # Spike/Nospike?
        dv = jnp.abs(voltage - prev_voltage)
        use_spike_net = dv > dv_treshold
        
        # Compute add_current using spike/nospike NNs
        neural_net_output = jax.lax.cond(use_spike_net, lambda: spike_neural_net(inputs), lambda: nospike_neural_net(inputs))
        u_time_constant = jax.lax.cond(use_spike_net, lambda: spike_u_time_constant, lambda: nospike_u_time_constant)
        u_new = u + dt*neural_net_output / u_time_constant

        readout_net_output = jax.lax.cond(use_spike_net, lambda: spike_readout_net(u_new), lambda: nospike_readout_net(u_new))
        add_current = readout_net_output.squeeze()
        



        total_current = current[t] + add_current * added_curr_std
        state, rec = step_fn(state, total_current)
        rec_voltage = rec[0]



      
        new_us, new_recs, new_adds, nn_reses = recs_adds
        new_recs = new_recs.at[t].set(rec_voltage)
        new_adds = new_adds.at[t].set(add_current)
        new_us = new_us.at[t].set(u_new)
        nn_reses = nn_reses.at[t].set(neural_net_output)

        new_diff = diff + (rec_voltage - x_o[t + 1])**2

        return (t + 1, state, u_new.squeeze(), (new_us, new_recs, new_adds, nn_reses), new_diff, voltage)


    # Initialize buffers
    recs = jnp.full((len(time_vec),), jnp.nan)
    adds = jnp.full((len(time_vec),), jnp.nan)
    us = jnp.full((len(time_vec), u_init.shape[0]), jnp.nan)
    nn_reses = jnp.full((len(time_vec), u_init.shape[0]), jnp.nan)

    carry = (0, initial_state, u_init.squeeze(), (us, recs, adds, nn_reses), 0.0, initial_state["v"][0].squeeze())

    final_carry = eqx.internal.while_loop(
        cond_fun=cond_fn,
        body_fun=body_fn,
        init_val=carry,
        max_steps=len(time_vec),
        kind="bounded"
    )

    _, _, _, (us, recs, adds, nn_reses), _, _ = final_carry

    return recs, adds, us, nn_reses

# %%
cost_fn_power = 1.0
scale = 0.05

def loss_fn(model, all_setup, t_max, i_amp, u_init, v_data, added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr=300, dtw_reg = 1.0, spike_reg = 2.0, sse_reg = 0.0, add_reg = 0.0):

    params = inv_transform_params(model.channel_params_normal)

    # Rebuild the simulator with new cell
    initial_state, step_fn, current, time_vec = setup_simulator_step(cell, cut, t_max, all_setup["v_init"], i_amp, params = params)

    # Run simulation
    preds, additional_currents, _, _ = simulate_full_trace(
        model.spike_neural_net, model.spike_readout_net, model.nospike_neural_net, model.nospike_readout_net, initial_state, step_fn, current, time_vec, u_init, v_data.squeeze(), added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr
    )

    preds = preds.squeeze()
    v_data = v_data.squeeze()

    sse_loss = jnp.sum(jnp.nan_to_num((preds - v_data) ** 2, nan=0.0))
    add_loss = jnp.sum(jnp.abs(jnp.nan_to_num(additional_currents, nan=0.0)))
    dtw_loss = get_scaled_loss(v_data, preds, cost_fn_power, scale)
    spike_loss = jnp.abs(jnp.max(preds) - jnp.max(v_data))
    
    return dtw_loss * dtw_reg + sse_loss * sse_reg + spike_loss * spike_reg + add_loss * add_reg

# %% [markdown]
# **Initialize and train**

# %%
u_dimension = 8
np.random.seed(42)
n_particles = 300

key1 = jax.random.PRNGKey(0)
key2 = jax.random.PRNGKey(1)
keys = jax.random.split(jax.random.PRNGKey(0), num=n_particles)

u_init = jnp.asarray(np.random.randn(u_dimension))  # Initial hidden state of the neural network
epsilon = 1e-4

all_setup = set_setup(setup)

# Different, random u_time_constant vectors
log_uniform_samples = jax.random.uniform(key1, shape=(u_dimension,), minval=np.log(1), maxval=np.log(100.0))
nospike_u_time_constant = jnp.exp(log_uniform_samples)

log_uniform_samples = jax.random.uniform(key2, shape=(u_dimension,), minval=np.log(0.1), maxval=np.log(10.0))
spike_u_time_constant = jnp.exp(log_uniform_samples)

added_curr_std = 1.0/10.0


thr = None


# Setup for learning rate scheduler
initial_lr = 15e-4
decay_factor = 0.99 
transition_steps = 1  # decay after every epoch
decay_start = 100 
decay_end = 250

# Initialize n_particles different parameter sets
opt_params = jax.vmap(sample_prior)(
    jax.random.split(init_rng_key, n_particles)
)


def initialize_model(key, init_params, u_dimension, W_matrices, epsilon):
    model = DoubleCorrectionModel(
        key=key,
        init_params=init_params,
        u_dimension=u_dimension,
        W_matrices=W_matrices,
        epsilon=epsilon
    )
    return model


models = jax.vmap(initialize_model, in_axes=(0, 0, None, None, None))(
    keys, opt_params, u_dimension, W_matrices, epsilon
)

# Scheduler
raw_schedule = optax.exponential_decay(
    init_value=initial_lr,
    transition_steps=transition_steps,
    decay_rate=decay_factor,
    staircase=True,
)

def custom_schedule(step):
    # Epochs before decay_start → constant
    lr = initial_lr

    # Epochs between decay_start and decay_end → decay
    decay_steps = jnp.clip(step - decay_start, 0, decay_end - decay_start)
    lr = jnp.where(
        step < decay_start,
        initial_lr,
        raw_schedule(decay_steps)
    )

    # After decay_end → freeze at last decayed value
    final_lr = raw_schedule(decay_end - decay_start)
    lr = jnp.where(step > decay_end, final_lr, lr)

    return lr

# Possible optimizers
adam_optimizer = optax.adam(learning_rate=custom_schedule)
lbfgs_optimizer = optax.chain(optax.scale_by_lbfgs(memory_size = 6), optax.scale(-1e-3))
adamw_optimizer = optax.adamw(learning_rate=custom_schedule, weight_decay=1e-4)

def init_adam_optimizer_state(model):
    return adam_optimizer.init(eqx.filter(model, eqx.is_inexact_array))

def init_lbfgs_optimizer_state(model):
    return lbfgs_optimizer.init(eqx.filter(model, eqx.is_inexact_array)) 

def init_adamw_optimizer_state(model):
    return adamw_optimizer.init(eqx.filter(model, eqx.is_inexact_array))


optimizer_states = jax.vmap(init_adam_optimizer_state)(models)
# optimizer_states = jax.vmap(init_adamw_optimizer_state)(models)
# optimizer_states = jax.vmap(init_lbfgs_optimizer_state)(models)


# Loss for optimization and fine-tuning
def simulation_loss_fn(all_params):
        loss = loss_fn(all_params, all_setup, t_max, i_amp, u_init, v_data, added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr, dtw_reg = 1.0, spike_reg = 2.0, sse_reg = 0.0, add_reg = 0.0)
        return loss

def fine_simulation_loss_fn(all_params):
        loss = loss_fn(all_params, all_setup, t_max, i_amp, u_init, v_data, added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr, dtw_reg = 0.0, spike_reg = 0.0, sse_reg = 1.0, add_reg = 0.0)
        return loss


grad_fn = nnx.jit(jax.vmap(nnx.value_and_grad(simulation_loss_fn)))
fine_grad_fn = nnx.jit(jax.vmap(nnx.value_and_grad(fine_simulation_loss_fn)))


# Set up the cell
cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])

cell.delete_stimuli()
cell.delete_recordings()

current = jx.step_current(50, 1000, i_amp, dt, t_max)
current = current[cut:]

cell.stimulate(current, verbose = False)
cell.record(verbose = False)
cell.set("v", all_setup['v_init'])
cell.init_states()

# %%
# Normalizing, scaling or clipping gradients
def clip_gradients(grads, max_norm=10.0, eps=1e-8):
    def clip_leaf(grad):
        flat = grad.reshape((grad.shape[0], -1)) if grad.ndim > 1 else grad[:, None]
        norms = jnp.linalg.norm(flat, axis=1, keepdims=True)
        scaling = jnp.minimum(1.0, max_norm / (norms + eps))
        while scaling.ndim < grad.ndim:
            scaling = scaling[..., None]
        return grad * scaling
    return jax.tree_util.tree_map(clip_leaf, grads)

def clip_channel_gradients(grads, max_norm=10.0, eps=1e-8):
    def clip_leaf(grad):
        flat = grad.reshape((grad.shape[0], -1)) if grad.ndim > 1 else grad[:, None]
        norms = jnp.linalg.norm(flat, axis=1, keepdims=True)
        scaling = jnp.minimum(1.0, max_norm / (norms + eps))
        while scaling.ndim < grad.ndim:
            scaling = scaling[..., None]
        return grad * scaling

    clipped = clip_leaf(grads.channel_params_normal)
    grads = eqx.tree_at(lambda g: g.channel_params_normal, grads, clipped)
    return grads

def clip_network_gradients(grads, max_norm=1.0, eps=1e-8):
    def clip_leaf(grad):
        if grad.ndim < 2:
            return grad  # Skip biases or scalars
        flat = grad.reshape((grad.shape[0], -1))
        norms = jnp.linalg.norm(flat, axis=1, keepdims=True)
        scaling = jnp.minimum(1.0, max_norm / (norms + eps))
        while scaling.ndim < grad.ndim:
            scaling = scaling[..., None]
        return grad * scaling

    def clip_net(net_grads):
        return jax.tree_util.tree_map(clip_leaf, net_grads)

    grads = eqx.tree_at(lambda g: g.spike_neural_net, grads, clip_net(grads.spike_neural_net))
    grads = eqx.tree_at(lambda g: g.spike_readout_net, grads, clip_net(grads.spike_readout_net))
    grads = eqx.tree_at(lambda g: g.nospike_neural_net, grads, clip_net(grads.nospike_neural_net))
    grads = eqx.tree_at(lambda g: g.nospike_readout_net, grads, clip_net(grads.nospike_readout_net))

    return grads

def normalize_gradients(grads, beta=1.0, eps=1e-8):
    def normalize_leaf(grad):
        norm = jnp.linalg.norm(grad, axis=1, keepdims=True)
        return grad / (norm ** beta + eps)

    grads = jax.tree_util.tree_map(normalize_leaf, grads)
    return grads

def normalize_channel_gradients(grads, beta=1.0, eps=1e-8):
    norms = jnp.linalg.norm(grads.channel_params_normal, axis=1, keepdims=True)
    normalized = grads.channel_params_normal / (norms ** beta + eps)

    # Replace only the channel_params_normal field
    grads = eqx.tree_at(lambda g: g.channel_params_normal, grads, normalized)
    return grads

def scale_grads(grads, lr_spike, lr_nospike, lr_channel):
    def scale_tree(tree, factor):
        return jax.tree_util.tree_map(lambda x: x * factor, tree)

    grads_scaled = grads

    grads_scaled = eqx.tree_at(lambda g: g.spike_neural_net, grads_scaled,
                            scale_tree(grads.spike_neural_net, lr_spike))
    grads_scaled = eqx.tree_at(lambda g: g.spike_readout_net, grads_scaled,
                            scale_tree(grads.spike_readout_net, lr_spike))
    grads_scaled = eqx.tree_at(lambda g: g.nospike_neural_net, grads_scaled,
                            scale_tree(grads.nospike_neural_net, lr_nospike))
    grads_scaled = eqx.tree_at(lambda g: g.nospike_readout_net, grads_scaled,
                            scale_tree(grads.nospike_readout_net, lr_nospike))
    grads_scaled = eqx.tree_at(lambda g: g.channel_params_normal, grads_scaled,
                            grads.channel_params_normal * lr_channel)

    return grads_scaled

# %%
num_epochs = 400
mean_losses = []

# Storing the best models and their losses during training
best_losses = jnp.full((1,), jnp.inf)
best_models = models  # Start with the initial models as best
grads_list = []
model_snapshots = []

for epoch in range(num_epochs):

    loss, grads = grad_fn(models)
    grads_list.append(grads)


   
    
    grads = clip_channel_gradients(grads, max_norm=10.0, eps=1e-8)
    #grads = scale_grads(grads, lr_spike=10, lr_nospike = 1e-2, lr_channel=1.0)
    grads = clip_network_gradients(grads, max_norm=10.0, eps=1e-8)



    improved = loss < best_losses
    best_losses = jnp.where(improved, loss, best_losses)

    def replace_if_improved(new, old):
        mask = improved.reshape((-1,) + (1,) * (new.ndim - 1))
        return jnp.where(mask, new, old)

    best_models = jax.tree_util.tree_map(replace_if_improved, models, best_models)

    mask = ~jnp.isnan(loss)
    mean_loss = jnp.sum(loss[mask]) / jnp.sum(mask)
    mean_losses.append(mean_loss)

    updates, optimizer_states = jax.vmap(lambda g, s, m: adam_optimizer.update(g, s, m, step = epoch))(grads, optimizer_states, models)
    models = jax.vmap(eqx.apply_updates)(models, updates)
    model_snapshots.append(jax.tree_util.tree_map(lambda x: x.copy(), models))

    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Mean Loss: {mean_loss:.6f}, Median Loss {jnp.median(loss[mask]):.6f}, Min Loss: {jnp.min(loss[mask]):.6f}")

        # print(jnp.max(jnp.linalg.norm(grads.channel_params_normal, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear1.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear1.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear2.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear2.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear3.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear3.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_readout_net.linear1.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_readout_net.linear1.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_readout_net.linear2.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_readout_net.linear2.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear1.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear1.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear2.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear2.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear3.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear3.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_readout_net.linear1.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_readout_net.linear1.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_readout_net.linear2.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_readout_net.linear2.bias, axis=1)))
# Out:
# /Users/moldor/anaconda3/envs/jaxley_env/lib/python3.12/site-packages/jax/_src/ops/scatter.py:93: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=float64 to dtype=float32 with jax_numpy_dtype_promotion='standard'. In future JAX releases this will result in an error.
#   warnings.warn(
# Epoch 0, Mean Loss: 265.668075, Median Loss 254.653715, Min Loss: 153.004894
# Epoch 10, Mean Loss: 242.635966, Median Loss 234.510184, Min Loss: 96.626785
# Epoch 20, Mean Loss: 231.723669, Median Loss 226.430151, Min Loss: 165.875064
# Epoch 30, Mean Loss: 219.073156, Median Loss 218.345840, Min Loss: 79.554145
# Epoch 40, Mean Loss: 212.080519, Median Loss 210.565067, Min Loss: 76.920996
# Epoch 50, Mean Loss: 204.520875, Median Loss 206.342713, Min Loss: 36.077582
# Epoch 60, Mean Loss: 205.721307, Median Loss 204.321282, Min Loss: 40.848096
# Epoch 70, Mean Loss: 195190.139114, Median Loss 202.557447, Min Loss: 52.044115
# Epoch 80, Mean Loss: 2994903191.322264, Median Loss 201.973665, Min Loss: 46.213337
# Epoch 90, Mean Loss: 230.307380, Median Loss 204.379336, Min Loss: 51.942279
# Epoch 100, Mean Loss: 113976868.053267, Median Loss 206.122933, Min Loss: 41.693490
# Epoch 110, Mean Loss: 869.989166, Median Loss 209.216157, Min Loss: 51.374580
# Epoch 120, Mean Loss: 256.344247, Median Loss 207.493496, Min Loss: 33.079897
# Epoch 130, Mean Loss: 265.851980, Median Loss 203.719279, Min Loss: 40.954163
# Epoch 140, Mean Loss: 309.991406, Median Loss 203.917468, Min Loss: 36.128501
# Epoch 150, Mean Loss: 360.478921, Median Loss 204.812680, Min Loss: 31.589989
# Epoch 160, Mean Loss: 285.352608, Median Loss 205.307402, Min Loss: 25.130336
# Epoch 170, Mean Loss: 48279.306213, Median Loss 209.013245, Min Loss: 35.301331
# Epoch 180, Mean Loss: 265.321877, Median Loss 209.026792, Min Loss: 33.873452
# Epoch 190, Mean Loss: 245.001247, Median Loss 207.213164, Min Loss: 26.376704
# Epoch 200, Mean Loss: 362.199742, Median Loss 207.002854, Min Loss: 25.177185
# Epoch 210, Mean Loss: 229.071785, Median Loss 206.128069, Min Loss: 26.640302
# Epoch 220, Mean Loss: 1085.365779, Median Loss 206.977182, Min Loss: 26.154303
# Epoch 230, Mean Loss: 12138.456125, Median Loss 207.979051, Min Loss: 30.430112
# Epoch 240, Mean Loss: 252.206372, Median Loss 203.632381, Min Loss: 24.816524
# Epoch 250, Mean Loss: 234.065181, Median Loss 202.475133, Min Loss: 24.134705
# Epoch 260, Mean Loss: 229.528828, Median Loss 202.292641, Min Loss: 27.609916
# Epoch 270, Mean Loss: 6818.258132, Median Loss 202.305406, Min Loss: 18.908625
# Epoch 280, Mean Loss: 227.206609, Median Loss 204.165978, Min Loss: 25.152230
# Epoch 290, Mean Loss: 10603.880592, Median Loss 203.211939, Min Loss: 17.447055
# Epoch 300, Mean Loss: 230.637126, Median Loss 206.140953, Min Loss: 24.640625
# Epoch 310, Mean Loss: 228.090211, Median Loss 204.255374, Min Loss: 20.610156
# Epoch 320, Mean Loss: 232.315994, Median Loss 203.092322, Min Loss: 23.555638
# Epoch 330, Mean Loss: 7685.040992, Median Loss 204.435277, Min Loss: 24.917903
# Epoch 340, Mean Loss: 236.304058, Median Loss 205.216896, Min Loss: 18.054095
# Epoch 350, Mean Loss: 236.392799, Median Loss 205.656355, Min Loss: 30.850458
# Epoch 360, Mean Loss: 7571164.586531, Median Loss 206.281608, Min Loss: 21.610946
# Epoch 370, Mean Loss: 1559.959900, Median Loss 201.911632, Min Loss: 23.168267
# Epoch 380, Mean Loss: 234.896846, Median Loss 203.186826, Min Loss: 22.106886
# Epoch 390, Mean Loss: 236.158524, Median Loss 201.017001, Min Loss: 18.678241

# %%
nan_mask = jnp.isnan(grads_list[num_epochs-1].channel_params_normal)

# Get indices where the mask is True
nan_indices = jnp.argwhere(nan_mask)
print("Not successfully trained models:", int(len(nan_indices)/15))
# Out:
# Not successfully trained models: 21

# %% [markdown]
# **Let's see the 10 best models**

# %%
#t=90.0, spike_reg = 2.0
inds = np.argsort(best_losses)

fig, axs = plt.subplots(2,5, figsize = (15,5))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
for i in range(2):
    for j in range(5):
        model = jax.tree_util.tree_map(lambda x: x[inds[i*5+j]], best_models)
        opt_inv_params = inv_transform_params(model.channel_params_normal)

        # Rebuild the simulator with new cell
        cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])

        cell.delete_stimuli()
        cell.delete_recordings()

        current = jx.step_current(50, 1000, i_amp, dt, t_max)
        current = current[cut:]

        cell.stimulate(current, verbose = False)
        cell.record(verbose = False)
        cell.set("v", all_setup['v_init'])
        cell.init_states()
        
        initial_state, step_fn, current, time_vec = setup_simulator_step(cell, cut, t_max, all_setup["v_init"], i_amp, params = opt_inv_params)

        # Run simulation
        final_preds, final_additional_currents, final_us, final_nn_reses = simulate_full_trace(
        model.spike_neural_net, model.spike_readout_net, model.nospike_neural_net, model.nospike_readout_net, initial_state, step_fn, current, time_vec, u_init, v_data.squeeze(), added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr
        )
        loss = get_scaled_loss(v_data[0], final_preds, cost_fn_power, scale)
        axs[i,j].plot(time_vec, v_data[0], label="Experimental target", linewidth=2)
        axs[i,j].plot(time_vec, final_preds, label="Single-compartment prediction", linestyle="--", linewidth=2)
        axs[i,j].set_title(f"Model {inds[i*5+j]}, Loss: {best_losses[inds[i*5+j]]:.4f},\n without reg: {loss:.4f}", fontsize = 10)
        axs[i,j].set_ylim(-100, 60)

# %%
#t=80.0, spike_reg = 2.0
inds = np.argsort(best_losses)
best_ten_preds = []
best_ten_losses = []

fig, axs = plt.subplots(2,5, figsize = (15,5))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
for i in range(2):
    for j in range(5):
        model = jax.tree_util.tree_map(lambda x: x[inds[i*5+j]], best_models)
        opt_inv_params = inv_transform_params(model.channel_params_normal)

        # Rebuild the simulator with new cell
        cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])

        cell.delete_stimuli()
        cell.delete_recordings()

        current = jx.step_current(50, 1000, i_amp, dt, t_max)
        current = current[cut:]

        cell.stimulate(current, verbose = False)
        cell.record(verbose = False)
        cell.set("v", all_setup['v_init'])
        cell.init_states()
        
        initial_state, step_fn, current, time_vec = setup_simulator_step(cell, cut, t_max, all_setup["v_init"], i_amp, params = opt_inv_params)

        # Run simulation
        final_preds, final_additional_currents, final_us, final_nn_reses = simulate_full_trace(
        model.spike_neural_net, model.spike_readout_net, model.nospike_neural_net, model.nospike_readout_net, initial_state, step_fn, current, time_vec, u_init, v_data.squeeze(), added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr
        )
        best_ten_preds.append(final_preds)
        best_ten_losses.append(best_losses[inds[i*5+j]])
        axs[i,j].plot(time_vec, v_data[0], label="Experimental target", linewidth=2)
        axs[i,j].plot(time_vec, final_preds, label="Single-compartment prediction", linestyle="--", linewidth=2)
        axs[i,j].set_title(f"Model {inds[i*5+j]}, Loss: {best_losses[inds[i*5+j]]:.4f}", fontsize = 10)
        axs[i,j].set_ylim(-100, 60)

best_ten_preds = np.stack(best_ten_preds)
np.save("../results/best_preds_two_nns.npy", best_ten_preds)
np.save("../results/losses_two_nns.npy", best_ten_losses)

# %% [markdown]
# **Checking one prediction:**

# %%
idx = 0
cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])
cell.delete_stimuli()
cell.delete_recordings()


current = jx.step_current(50, 1000, i_amp, dt, t_max)
current = current[cut:]

cell.stimulate(current)
cell.record()
cell.set("v", all_setup['v_init'])
cell.init_states()

model = jax.tree_util.tree_map(lambda x: x[inds[idx]], best_models)
opt_inv_params = inv_transform_params(model.channel_params_normal)

# Rebuild the simulator with new cell
initial_state, step_fn, current, time_vec = setup_simulator_step(cell, cut, t_max, all_setup["v_init"], i_amp, params = opt_inv_params)

# Run simulation
final_preds, final_additional_currents, final_us, final_nn_reses = simulate_full_trace(
    model.spike_neural_net, model.spike_readout_net, model.nospike_neural_net, model.nospike_readout_net, initial_state, step_fn, current, time_vec, u_init, v_data.squeeze(), added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr
)

loss = simulation_loss_fn(model)


plt.plot(v_data[0], label="Data target", linewidth=2)
plt.plot(final_preds, label="Single-compartment prediction", linestyle="--", linewidth=2)
plt.title(f"Loss: {loss:.4f}")
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
plt.legend(["Target", "Prediction"])
# Out:
# Added 1 external_states. See `.externals` for details.
# Added 1 recordings. See `.recordings` for details.

# %%
fig, axs = plt.subplots(1,3, figsize = (15,3))
axs[0].plot(time_vec, final_us)
axs[0].set_title("Hidden state (u)")
axs[1].plot(time_vec, final_nn_reses)
axs[1].set_title("Dynamics network output (neural_net)")
axs[2].plot(time_vec, final_additional_currents)
axs[2].set_title("Additional current")

np.save("../results/best_model_u.npy", final_us)
np.save("../results/best_model_nn_reses.npy", final_nn_reses)
np.save("../results/best_model_additional_currents.npy", final_additional_currents * added_curr_std)

# %% [markdown]
# **How does it generalize for a longer period?**

# %%
idx = 0
cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])
cell.delete_stimuli()
cell.delete_recordings()

t_max_long = 250.0

current = jx.step_current(50, 1000, i_amp, dt, t_max_long)
current = current[cut:]

t, v_data_long, i_amp = get_experimental_data(setup, cut, t_max_long)
v_data_long = jnp.asarray(v_data_long[None,])

cell.stimulate(current)
cell.record()
cell.set("v", all_setup['v_init'])
cell.init_states()

model = jax.tree_util.tree_map(lambda x: x[inds[idx]], best_models)
opt_inv_params = inv_transform_params(model.channel_params_normal)

# Rebuild the simulator with new cell
initial_state, step_fn, current, time_vec = setup_simulator_step(cell, cut, t_max_long, all_setup["v_init"], i_amp, params = opt_inv_params)

# Run simulation
final_preds, final_additional_currents, final_us, final_nn_reses = simulate_full_trace(
    model.spike_neural_net, model.spike_readout_net, model.nospike_neural_net, model.nospike_readout_net, initial_state, step_fn, current, time_vec, u_init, v_data_long.squeeze(), added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr
)



plt.plot(v_data_long[0], label="Data target", linewidth=2)
plt.plot(final_preds, label="Single-compartment prediction", linestyle="--", linewidth=2)
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
plt.legend(["Target", "Prediction"])

np.save("../results/best_model_pred_long.npy", final_preds)
np.save("../results/best_model_data_long.npy", v_data_long)
# Out:
# dt_difference 5.0
# Amplitude stimulus: 0.20999999344348907
# Added 1 external_states. See `.externals` for details.
# Added 1 recordings. See `.recordings` for details.

# %%
fig, axs = plt.subplots(1,3, figsize = (15,3))
axs[0].plot(time_vec, final_us)
axs[0].set_title("Hidden state (u)")
axs[1].plot(time_vec, final_nn_reses)
axs[1].set_title("Dynamics network output (neural_net)")
axs[2].plot(time_vec, final_additional_currents)
axs[2].set_title("Additional current")
# Out:
# Text(0.5, 1.0, 'Additional current')

# %% [markdown]
# **What are the channel parameters after training?**

# %%
import matplotlib as mpl
names, lower, upper = get_bounds()

opt_inv_params_list = []
for i in range(10):
    model = jax.tree_util.tree_map(lambda x: x[inds[i]], best_models)
    opt_inv_params = inv_transform_params(model.channel_params_normal)
    opt_inv_params_list.append(opt_inv_params)

param_matrix = np.stack(opt_inv_params_list)

# Normalize
normalized_params = (param_matrix - lower) / (upper - lower)
normalized_params = np.clip(normalized_params, 0, 1)


with mpl.rc_context(fname="../../../.matplotlibrc"):
    fig, ax = plt.subplots(figsize=(5, 4))
    indices = np.arange(len(opt_inv_params))

    # Draw the [0, 1] range
    ax.hlines(indices, 0, 1, color='lightgray', linewidth=5, zorder=1)
    colors = plt.cm.tab10(np.linspace(0, 1, 10))
    colors = plt.cm.Pastel1(np.linspace(0, 1, 10))
    colors = plt.cm.viridis(np.linspace(0.0, 1.0, 10))
    sizes = np.linspace(50, 15, 10)
    alphas = np.linspace(1.0, 0.5, 10)


    # Plot all models
    for j in range(10):
        ax.scatter(normalized_params[j], indices, color=colors[j], s=sizes[j], alpha = alphas[j], label=f'Model {j+1}', zorder=2)

    # Annotate only the best model (j == 0)
    for k in range(len(names)):
        x = normalized_params[0, k]
        y = k
        val = param_matrix[0, k]
        ax.text(x - 0.03, y + 0.5, f"{val:.3f}", fontsize=8, color='k', va='center')


    ax.set_yticks(indices)
    ax.set_yticklabels(names)
    ax.set_xlim(-0.00, 1.02)
    ax.set_xlabel("Normalized parameter value")
    ax.set_title("Normalized Optimized Parameters from 10 Best Models", fontsize = 9, pad = 10)
    ax.grid(True, axis='x', linestyle='--', alpha=0.5)

    fig.savefig("../svg/optimized_parameters_two_nns.svg", bbox_inches='tight')

    plt.tight_layout()
    plt.show()
# Out:
# Number of parameters: 15

# %% [markdown]
# **Fine-tuning the best 40 models with SSE loss**

# %%
t_max = 80.0
top_k = 40
top_k_inds = inds[:top_k]
top_k_models = jax.tree_util.tree_map(lambda x: x[top_k_inds], best_models)
top_k_losses = jnp.full((top_k,), jnp.inf)

fine_tune_lr = 5e-4
decay_start = 100
decay_end = 200


fine_schedule = optax.exponential_decay(
    init_value=fine_tune_lr,
    transition_steps=1,
    decay_rate=0.99,
    staircase=True,
)
def fine_custom_schedule(step):
    # Epochs before decay_start → constant
    lr = fine_tune_lr

    # Epochs between decay_start and decay_end → decay
    decay_steps = jnp.clip(step - decay_start, 0, decay_end - decay_start)
    lr = jnp.where(
        step < decay_start,
        fine_tune_lr,
        fine_schedule(decay_steps)
    )

    # After decay_end → freeze at last decayed value
    final_lr = fine_schedule(decay_end - decay_start)
    lr = jnp.where(step > decay_end, final_lr, lr)

    return lr

fine_optimizer = optax.adam(fine_custom_schedule)
# fine_optimizer = optax.sgd(learning_rate=1e-8, momentum=0.9)
# fine_optimizer = optax.chain(
#             optax.scale_by_lbfgs(memory_size = 8), #8
#             optax.scale(-1e-3), #0.3
#         )

fine_optimizer_states = jax.vmap(lambda m: fine_optimizer.init(eqx.filter(m, eqx.is_inexact_array)))(top_k_models)

cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])
cell.delete_stimuli()
cell.delete_recordings()


current = jx.step_current(50, 1000, i_amp, dt, t_max)
current = current[cut:]

cell.stimulate(current)
cell.record()
cell.set("v", all_setup['v_init'])
cell.init_states()

num_fine_epochs = 300
fine_mean_losses = []
fine_best_models = top_k_models
fine_best_losses = top_k_losses

for epoch in range(num_fine_epochs):

    loss, grads = fine_grad_fn(top_k_models)

    #grads = clip_channel_gradients(grads, max_norm=10.0, eps=1e-8)
    #grads = eqx.tree_at(lambda g: g.channel_params_normal, grads, jnp.zeros_like(grads.channel_params_normal))
    #grads = scale_grads(grads, lr_spike=10.0, lr_nospike = 1e-2, lr_channel=1.0)
    
    grads = clip_network_gradients(grads, max_norm=10.0, eps=1e-8)
    grads = clip_channel_gradients(grads, max_norm=10.0, eps=1e-8)

    improved = loss < fine_best_losses
    fine_best_losses = jnp.where(improved, loss, fine_best_losses)
    fine_best_models = jax.tree_util.tree_map(replace_if_improved, top_k_models, fine_best_models)

    updates, fine_optimizer_states = jax.vmap(lambda g, s, m: fine_optimizer.update(g, s, m, step=epoch))(grads, fine_optimizer_states, top_k_models)
    top_k_models = jax.vmap(eqx.apply_updates)(top_k_models, updates)

    mask = ~jnp.isnan(loss)
    fine_mean_loss = jnp.sum(loss[mask]) / jnp.sum(mask)

    fine_mean_losses.append(fine_mean_loss)

    if epoch % 10 == 0:
        print(f"Fine-tune epoch {epoch}, Mean Loss: {fine_mean_loss:.6f}, Median Loss {jnp.median(loss[mask]):.6f}, Min Loss: {jnp.min(loss[mask]):.6f}")
        # print(jnp.max(jnp.linalg.norm(grads.channel_params_normal, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear1.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear1.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear2.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear2.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear3.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear3.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_readout_net.linear1.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_readout_net.linear1.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_readout_net.linear2.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_readout_net.linear2.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear1.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear1.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear2.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear2.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear3.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear3.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_readout_net.linear1.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_readout_net.linear1.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_readout_net.linear2.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_readout_net.linear2.bias, axis=1)))
# Out:
# Added 1 external_states. See `.externals` for details.
# Added 1 recordings. See `.recordings` for details.
# /Users/moldor/anaconda3/envs/jaxley_env/lib/python3.12/site-packages/jax/_src/ops/scatter.py:93: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=float64 to dtype=float32 with jax_numpy_dtype_promotion='standard'. In future JAX releases this will result in an error.
#   warnings.warn(
# Fine-tune epoch 0, Mean Loss: 49453.813550, Median Loss 37717.550781, Min Loss: 9054.376953
# Fine-tune epoch 10, Mean Loss: 127188.918823, Median Loss 85350.789062, Min Loss: 10511.126953
# Fine-tune epoch 20, Mean Loss: 100338.369946, Median Loss 84294.921875, Min Loss: 10782.641602
# Fine-tune epoch 30, Mean Loss: 74727.116650, Median Loss 49148.552734, Min Loss: 10383.191406
# Fine-tune epoch 40, Mean Loss: 92978.638892, Median Loss 66648.777344, Min Loss: 9405.550781
# Fine-tune epoch 50, Mean Loss: 76434.075256, Median Loss 50809.156250, Min Loss: 7971.481934
# Fine-tune epoch 60, Mean Loss: 74682.520947, Median Loss 47516.865234, Min Loss: 10167.962891
# Fine-tune epoch 70, Mean Loss: 69961.725659, Median Loss 60236.685547, Min Loss: 9365.273438
# Fine-tune epoch 80, Mean Loss: 83626.551001, Median Loss 41506.292969, Min Loss: 7510.994141
# Fine-tune epoch 90, Mean Loss: 78147.813342, Median Loss 48670.955078, Min Loss: 8114.342285
# Fine-tune epoch 100, Mean Loss: 96415.185400, Median Loss 55734.330078, Min Loss: 8590.270508
# Fine-tune epoch 110, Mean Loss: 68832.787988, Median Loss 51554.271484, Min Loss: 7615.108398
# Fine-tune epoch 120, Mean Loss: 56562.706982, Median Loss 35041.693359, Min Loss: 9293.969727
# Fine-tune epoch 130, Mean Loss: 61383.330322, Median Loss 38362.527344, Min Loss: 9079.310547
# Fine-tune epoch 140, Mean Loss: 73552.146045, Median Loss 53352.345703, Min Loss: 8014.816406
# Fine-tune epoch 150, Mean Loss: 60170.361646, Median Loss 28986.523438, Min Loss: 9850.934570
# Fine-tune epoch 160, Mean Loss: 63839.417871, Median Loss 43024.595703, Min Loss: 8060.945312
# Fine-tune epoch 170, Mean Loss: 54221.584839, Median Loss 36517.082031, Min Loss: 8679.308594
# Fine-tune epoch 180, Mean Loss: 51266.690161, Median Loss 29295.443359, Min Loss: 8830.119141
# Fine-tune epoch 190, Mean Loss: 67960.585510, Median Loss 39466.058594, Min Loss: 7158.762207
# Fine-tune epoch 200, Mean Loss: 60973.763513, Median Loss 36474.395508, Min Loss: 7086.098633
# Fine-tune epoch 210, Mean Loss: 49058.854407, Median Loss 24160.564453, Min Loss: 6794.070801
# Fine-tune epoch 220, Mean Loss: 49104.112939, Median Loss 26153.450195, Min Loss: 7499.064453
# Fine-tune epoch 230, Mean Loss: 50049.311694, Median Loss 27684.381836, Min Loss: 6869.499512
# Fine-tune epoch 240, Mean Loss: 54577.476550, Median Loss 25651.083008, Min Loss: 6551.805664
# Fine-tune epoch 250, Mean Loss: 54199.880688, Median Loss 25044.938477, Min Loss: 7739.351562
# Fine-tune epoch 260, Mean Loss: 44727.190601, Median Loss 27722.094727, Min Loss: 7485.181641
# Fine-tune epoch 270, Mean Loss: 50236.886731, Median Loss 23339.708984, Min Loss: 6502.510254
# Fine-tune epoch 280, Mean Loss: 46159.095508, Median Loss 23618.115234, Min Loss: 5682.191406
# Fine-tune epoch 290, Mean Loss: 48905.829736, Median Loss 24130.876953, Min Loss: 7172.423828

# %%
fine_inds = np.argsort(fine_best_losses)
fig, axs = plt.subplots(2,5, figsize = (20,6))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle("Best fine-tuned models", fontsize=16)
for i in range(2):
    for j in range(5):
        model = jax.tree_util.tree_map(lambda x: x[fine_inds[i*5+j]], fine_best_models)
        opt_inv_params = inv_transform_params(model.channel_params_normal)

        # Rebuild the simulator with new cell
        cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])

        cell.delete_stimuli()
        cell.delete_recordings()

        current = jx.step_current(50, 1000, i_amp, dt, t_max)
        current = current[cut:]

        cell.stimulate(current, verbose = False)
        cell.record(verbose = False)
        # cell.soma.branch(0).comp(0).stimulate(current, verbose = False)
        # cell.soma.branch(0).comp(0).record(verbose = False)
        cell.set("v", all_setup['v_init'])
        cell.init_states()
        
        initial_state, step_fn, current, time_vec = setup_simulator_step(cell, cut, t_max, all_setup["v_init"], i_amp, params = opt_inv_params)

        # Run simulation
        final_preds, final_additional_currents, final_us, final_nn_reses = simulate_full_trace(
            model.spike_neural_net, model.spike_readout_net, model.nospike_neural_net, model.nospike_readout_net, initial_state, step_fn, current, time_vec, u_init, v_data.squeeze(), added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr
        )
        axs[i,j].plot(time_vec, v_data[0], label="Experimental target", linewidth=2)
        axs[i,j].plot(time_vec, final_preds, label="Single-compartment prediction", linestyle="--", linewidth=2)
        axs[i,j].set_title(f"Model {inds[fine_inds[i*5+j]]}, Loss: {fine_best_losses[fine_inds[i*5+j]]:.4f}", fontsize = 10)
        axs[i,j].set_ylim(-100, 60)

# %%
idx = 1
cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])
cell.delete_stimuli()
cell.delete_recordings()


current = jx.step_current(50, 1000, i_amp, dt, t_max)
current = current[cut:]

cell.stimulate(current)
cell.record()
cell.set("v", all_setup['v_init'])
cell.init_states()

def fine_simulation_loss_fn(all_params):
        loss = loss_fn(all_params, all_setup, t_max, i_amp, u_init, v_data, added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr, dtw_reg = 0.0, spike_reg = 0.0, sse_reg = 1.0, add_reg = 0.0)
        return loss

model = jax.tree_util.tree_map(lambda x: x[fine_inds[idx]], fine_best_models)
opt_inv_params = inv_transform_params(model.channel_params_normal)

# Rebuild the simulator with new cell
initial_state, step_fn, current, time_vec = setup_simulator_step(cell, cut, t_max, all_setup["v_init"], i_amp, params = opt_inv_params)

# Run simulation
final_preds, final_additional_currents, final_us, final_nn_reses = simulate_full_trace(
    model.spike_neural_net, model.spike_readout_net, model.nospike_neural_net, model.nospike_readout_net, initial_state, step_fn, current, time_vec, u_init, v_data.squeeze(), added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr
)

loss = fine_simulation_loss_fn(model)


plt.plot(v_data[0], label="Data target", linewidth=2)
plt.plot(final_preds, label="Single-compartment prediction", linestyle="--", linewidth=2)
plt.title(f"Loss: {loss:.4f}")
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
plt.legend(["Target", "Prediction"])
# Out:
# Added 1 external_states. See `.externals` for details.
# Added 1 recordings. See `.recordings` for details.

# %%
fig, axs = plt.subplots(1,3, figsize = (15,3))
axs[0].plot(time_vec, final_us)
axs[0].set_title("Hidden state (u)")
axs[1].plot(time_vec, final_nn_reses)
axs[1].set_title("Dynamics network output (neural_net)")
axs[2].plot(time_vec, final_additional_currents)
axs[2].set_title("Additional current")
# Out:
# Text(0.5, 1.0, 'Additional current')

# %% [markdown]
# **Can we train at least 1 model better than before? - Not really...**

# %%
idx = 0
model = jax.tree_util.tree_map(lambda x: x[None, fine_inds[idx]], fine_best_models)

one_lr = 5e-5 
decay_start = 100
decay_end = 200


one_schedule = optax.exponential_decay(
    init_value=one_lr,
    transition_steps=1,
    decay_rate=0.99,
    staircase=True,
)
def one_custom_schedule(step):
    # Epochs before decay_start → constant
    lr = one_lr

    # Epochs between decay_start and decay_end → decay
    decay_steps = jnp.clip(step - decay_start, 0, decay_end - decay_start)
    lr = jnp.where(
        step < decay_start,
        one_lr,
        one_schedule(decay_steps)
    )

    # After decay_end → freeze at last decayed value
    final_lr = one_schedule(decay_end - decay_start)
    lr = jnp.where(step > decay_end, final_lr, lr)

    return lr

one_optimizer = optax.adam(one_custom_schedule)
one_optimizer_state = one_optimizer.init(eqx.filter(model, eqx.is_inexact_array))

def fine_simulation_loss_fn(all_params):
        loss = loss_fn(all_params, all_setup, t_max, i_amp, u_init, v_data, added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr, dtw_reg = 0.0, spike_reg = 0.0, sse_reg = 1.0, add_reg = 0.0)
        return loss


fine_grad_fn = nnx.jit(jax.vmap(nnx.value_and_grad(fine_simulation_loss_fn)))

num_one_epochs = 1000
one_best_model = model
one_best_loss = jnp.inf
one_mean_losses = []

for epoch in range(num_one_epochs):
    loss, grads = fine_grad_fn(model)

    grads = clip_channel_gradients(grads, max_norm=10.0, eps=1e-8)
    grads = clip_network_gradients(grads, max_norm=10.0, eps=1e-8)

    if loss < one_best_loss:
        one_best_loss = loss
        one_best_model = model

    updates, one_optimizer_state = one_optimizer.update(grads, one_optimizer_state, model, step=epoch)
    model = eqx.apply_updates(model, updates)

    one_mean_losses.append(loss)

    if epoch % 10 == 0:
        print(f"One-tune epoch {epoch}, Loss: {jnp.mean(loss):.6f}")
# Out:
# /Users/moldor/anaconda3/envs/jaxley_env/lib/python3.12/site-packages/jax/_src/ops/scatter.py:93: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=float64 to dtype=float32 with jax_numpy_dtype_promotion='standard'. In future JAX releases this will result in an error.
#   warnings.warn(
# One-tune epoch 0, Loss: 5682.191406
# One-tune epoch 10, Loss: 5761.206055
# One-tune epoch 20, Loss: 6703.516602
# One-tune epoch 30, Loss: 5743.009277
# One-tune epoch 40, Loss: 5653.155273
# One-tune epoch 50, Loss: 5732.836914
# One-tune epoch 60, Loss: 5620.251953
# One-tune epoch 70, Loss: 5606.056152
# One-tune epoch 80, Loss: 5991.116211
# One-tune epoch 90, Loss: 8379.650391
# One-tune epoch 100, Loss: 6127.048340
# One-tune epoch 110, Loss: 7623.183105
# One-tune epoch 120, Loss: 7710.188477
# One-tune epoch 130, Loss: 5977.768066
# One-tune epoch 140, Loss: 5738.551270
# One-tune epoch 150, Loss: 5585.018066
# One-tune epoch 160, Loss: 5669.688477
# One-tune epoch 170, Loss: 7373.619141
# One-tune epoch 180, Loss: 7138.607910
# One-tune epoch 190, Loss: 6250.476562
# One-tune epoch 200, Loss: 6987.867676
# One-tune epoch 210, Loss: 6817.341309
# One-tune epoch 220, Loss: 6717.423828
# One-tune epoch 230, Loss: 5829.311035
# One-tune epoch 240, Loss: 6546.571289
# One-tune epoch 250, Loss: 5825.586914
# One-tune epoch 260, Loss: 5922.355957
# One-tune epoch 270, Loss: 5890.052246
# One-tune epoch 280, Loss: 6406.358398
# One-tune epoch 290, Loss: 5911.939453
# One-tune epoch 300, Loss: 6387.635742
# One-tune epoch 310, Loss: 5891.931641
# One-tune epoch 320, Loss: 6383.094238
# One-tune epoch 330, Loss: 5866.730469
# One-tune epoch 340, Loss: 6383.500488
# One-tune epoch 350, Loss: 5840.710938
# One-tune epoch 360, Loss: 6355.929199
# One-tune epoch 370, Loss: 5870.521973
# One-tune epoch 380, Loss: 6339.748535
# One-tune epoch 390, Loss: 5854.310547
# One-tune epoch 400, Loss: 6337.471191
# One-tune epoch 410, Loss: 5830.921875
# One-tune epoch 420, Loss: 6338.388672
# One-tune epoch 430, Loss: 5806.398438
# One-tune epoch 440, Loss: 6340.488281
# One-tune epoch 450, Loss: 5782.188965
# One-tune epoch 460, Loss: 6343.317871
# One-tune epoch 470, Loss: 5781.084961
# One-tune epoch 480, Loss: 6287.460938
# One-tune epoch 490, Loss: 5823.480957
# One-tune epoch 500, Loss: 6260.480469
# One-tune epoch 510, Loss: 5819.530273
# One-tune epoch 520, Loss: 6251.897949
# One-tune epoch 530, Loss: 5802.120117
# One-tune epoch 540, Loss: 6252.318848
# One-tune epoch 550, Loss: 5778.340332
# One-tune epoch 560, Loss: 6255.500488
# One-tune epoch 570, Loss: 5753.671875
# One-tune epoch 580, Loss: 6259.873535
# One-tune epoch 590, Loss: 5730.041016
# One-tune epoch 600, Loss: 6264.357422
# One-tune epoch 610, Loss: 5707.468750
# One-tune epoch 620, Loss: 6269.478027
# One-tune epoch 630, Loss: 5685.562988
# One-tune epoch 640, Loss: 6274.741211
# One-tune epoch 650, Loss: 5664.081055
# One-tune epoch 660, Loss: 6278.971680
# One-tune epoch 670, Loss: 5641.356445
# One-tune epoch 680, Loss: 6281.281250
# One-tune epoch 690, Loss: 5617.864746
# One-tune epoch 700, Loss: 6284.391602
# One-tune epoch 710, Loss: 5594.846191
# One-tune epoch 720, Loss: 6289.858398
# One-tune epoch 730, Loss: 5572.994629
# One-tune epoch 740, Loss: 6297.560059
# One-tune epoch 750, Loss: 5551.798340
# One-tune epoch 760, Loss: 6307.268555
# One-tune epoch 770, Loss: 5531.440918
# One-tune epoch 780, Loss: 6318.724121
# One-tune epoch 790, Loss: 5511.738281
# One-tune epoch 800, Loss: 6332.361328
# One-tune epoch 810, Loss: 5492.539062
# One-tune epoch 820, Loss: 6348.525879
# One-tune epoch 830, Loss: 5471.708984
# One-tune epoch 840, Loss: 6399.784668
# One-tune epoch 850, Loss: 5442.738770
# One-tune epoch 860, Loss: 6430.665527
# One-tune epoch 870, Loss: 5425.604492
# One-tune epoch 880, Loss: 6457.216309
# One-tune epoch 890, Loss: 5408.616699
# One-tune epoch 900, Loss: 6484.962891
# One-tune epoch 910, Loss: 5388.671875
# One-tune epoch 920, Loss: 6588.033203
# One-tune epoch 930, Loss: 5365.292969
# One-tune epoch 940, Loss: 6611.691895
# One-tune epoch 950, Loss: 5367.567871
# One-tune epoch 960, Loss: 5440.641602
# One-tune epoch 970, Loss: 6578.607910
# One-tune epoch 980, Loss: 6489.145996
# One-tune epoch 990, Loss: 5472.192383

# %%
idx = 0

cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])
#cell = build_cell(all_setup["swc_fname"], all_setup["rotation"], all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'])

cell.delete_stimuli()
cell.delete_recordings()

current = jx.step_current(50, 1000, i_amp, dt, t_max)
current = current[cut:]

cell.stimulate(current)
cell.record()
# cell.soma.branch(0).comp(0).stimulate(current)
# cell.soma.branch(0).comp(0).record()
cell.set("v", all_setup['v_init'])
cell.init_states()

model = jax.tree_util.tree_map(lambda x: x[0], model)

opt_inv_params = inv_transform_params(model.channel_params_normal)

# Rebuild the simulator with new cell
initial_state, step_fn, current, time_vec = setup_simulator_step(cell, cut, t_max, all_setup["v_init"], i_amp, params = opt_inv_params)

# Run simulation
final_preds, final_additional_currents, final_us, final_nn_reses = simulate_full_trace(
    model.spike_neural_net, model.spike_readout_net, model.nospike_neural_net, model.nospike_readout_net, initial_state, step_fn, current, time_vec, u_init, v_data.squeeze(), added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr
)

loss = fine_simulation_loss_fn(model)


plt.plot(v_data[0], label="Data target", linewidth=2)
plt.plot(final_preds, label="Single-compartment prediction", linestyle="--", linewidth=2)
plt.title(f"Loss: {loss:.4f}")
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
plt.legend(["Target", "Prediction"])
# Out:
# Added 1 external_states. See `.externals` for details.
# Added 1 recordings. See `.recordings` for details.

# %%
fig, axs = plt.subplots(1,3, figsize = (15,3))
axs[0].plot(time_vec, final_us)
axs[0].set_title("Hidden state (u)")
axs[1].plot(time_vec, final_nn_reses)
axs[1].set_title("Dynamics network output (neural_net)")
axs[2].plot(time_vec, final_additional_currents)
axs[2].set_title("Additional current")
# Out:
# Text(0.5, 1.0, 'Additional current')

# %% [markdown]
# **Fine-tuning for a longer period of data**

# %%
top_k = 20
top_k_inds = inds[:top_k]
top_k_models = jax.tree_util.tree_map(lambda x: x[top_k_inds], best_models)
top_k_losses = jnp.full((top_k,), jnp.inf)

fine_tune_lr = 5e-4 
decay_start = 100
decay_end = 200


fine_schedule = optax.exponential_decay(
    init_value=fine_tune_lr,
    transition_steps=1,
    decay_rate=0.99,
    staircase=True,
)
def fine_custom_schedule(step):
    # Epochs before decay_start → constant
    lr = fine_tune_lr

    # Epochs between decay_start and decay_end → decay
    decay_steps = jnp.clip(step - decay_start, 0, decay_end - decay_start)
    lr = jnp.where(
        step < decay_start,
        fine_tune_lr,
        fine_schedule(decay_steps)
    )

    # After decay_end → freeze at last decayed value
    final_lr = fine_schedule(decay_end - decay_start)
    lr = jnp.where(step > decay_end, final_lr, lr)

    return lr

fine_optimizer = optax.adam(fine_custom_schedule)
# fine_optimizer = optax.sgd(learning_rate=1e-8, momentum=0.9)
# fine_optimizer = optax.chain(
#             optax.scale_by_lbfgs(memory_size = 8), #8
#             optax.scale(-1e-3), #0.3
#         )

fine_optimizer_states = jax.vmap(lambda m: fine_optimizer.init(eqx.filter(m, eqx.is_inexact_array)))(top_k_models)



def fine_simulation_loss_fn(all_params):
        loss = loss_fn(all_params, all_setup, t_max_long, i_amp, u_init, v_data_long, added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr, dtw_reg = 0.0, spike_reg = 0.0, sse_reg = 1.0, add_reg = 0.0)
        return loss


fine_grad_fn = nnx.jit(jax.vmap(nnx.value_and_grad(fine_simulation_loss_fn)))

cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])
cell.delete_stimuli()
cell.delete_recordings()


current = jx.step_current(50, 1000, i_amp, dt, t_max_long)
current = current[cut:]

cell.stimulate(current)
cell.record()
cell.set("v", all_setup['v_init'])
cell.init_states()

num_fine_epochs = 300
fine_mean_losses_long = []
fine_best_models_long = top_k_models
fine_best_losses_long = top_k_losses

for epoch in range(num_fine_epochs):

    loss, grads = fine_grad_fn(top_k_models)

    #grads = clip_channel_gradients(grads, max_norm=10.0, eps=1e-8)
    #grads = eqx.tree_at(lambda g: g.channel_params_normal, grads, jnp.zeros_like(grads.channel_params_normal))
    #grads = scale_grads(grads, lr_spike=10.0, lr_nospike = 1e-2, lr_channel=1.0)
    
    grads = clip_network_gradients(grads, max_norm=10.0, eps=1e-8)
    grads = clip_channel_gradients(grads, max_norm=10.0, eps=1e-8)

    improved = loss < fine_best_losses_long
    fine_best_losses_long = jnp.where(improved, loss, fine_best_losses_long)
    fine_best_models_long = jax.tree_util.tree_map(replace_if_improved, top_k_models, fine_best_models_long)

    updates, fine_optimizer_states = jax.vmap(lambda g, s, m: fine_optimizer.update(g, s, m, step=epoch))(grads, fine_optimizer_states, top_k_models)
    top_k_models = jax.vmap(eqx.apply_updates)(top_k_models, updates)

    mask = ~jnp.isnan(loss)
    fine_mean_loss = jnp.sum(loss[mask]) / jnp.sum(mask)

    fine_mean_losses_long.append(jnp.mean(fine_mean_loss))

    if epoch % 10 == 0:
        print(f"Fine-tune epoch {epoch}, Mean Loss: {jnp.mean(fine_mean_loss):.6f}, Median Loss {jnp.median(loss[mask]):.6f}, Min Loss: {jnp.min(loss[mask]):.6f}")
        # print(jnp.max(jnp.linalg.norm(grads.channel_params_normal, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear1.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear1.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear2.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear2.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear3.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_neural_net.linear3.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_readout_net.linear1.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_readout_net.linear1.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.spike_readout_net.linear2.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.spike_readout_net.linear2.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear1.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear1.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear2.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear2.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear3.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_neural_net.linear3.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_readout_net.linear1.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_readout_net.linear1.bias, axis=1)),
        #   jnp.max(jnp.linalg.norm(grads.nospike_readout_net.linear2.weight, axis=2)), jnp.max(jnp.linalg.norm(grads.nospike_readout_net.linear2.bias, axis=1)))
# Out:
# Added 1 external_states. See `.externals` for details.
# Added 1 recordings. See `.recordings` for details.
# /Users/moldor/anaconda3/envs/jaxley_env/lib/python3.12/site-packages/jax/_src/ops/scatter.py:93: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=float64 to dtype=float32 with jax_numpy_dtype_promotion='standard'. In future JAX releases this will result in an error.
#   warnings.warn(
# Fine-tune epoch 0, Mean Loss: 116934672712252480.000000, Median Loss 13080110.500000, Min Loss: 1392263.375000
# Fine-tune epoch 10, Mean Loss: 62263343.201389, Median Loss 2439311.125000, Min Loss: 871666.437500
# Fine-tune epoch 20, Mean Loss: 2363909.597222, Median Loss 1728037.875000, Min Loss: 643944.562500
# Fine-tune epoch 30, Mean Loss: 5540547433.993055, Median Loss 1546990.437500, Min Loss: 544432.750000
# Fine-tune epoch 40, Mean Loss: 9696552.994792, Median Loss 1624226.250000, Min Loss: 462277.125000
# Fine-tune epoch 50, Mean Loss: 424117769.045139, Median Loss 2065899.437500, Min Loss: 440627.125000
# Fine-tune epoch 60, Mean Loss: 2537544636.619792, Median Loss 1133743.500000, Min Loss: 440635.750000
# Fine-tune epoch 70, Mean Loss: 637458034.192708, Median Loss 1223390.906250, Min Loss: 439286.281250
# Fine-tune epoch 80, Mean Loss: 17912443.015625, Median Loss 972225.093750, Min Loss: 438508.406250
# Fine-tune epoch 90, Mean Loss: 774466240.225694, Median Loss 772982.562500, Min Loss: 437993.812500
# Fine-tune epoch 100, Mean Loss: 1278147.251736, Median Loss 719114.125000, Min Loss: 437452.031250
# Fine-tune epoch 110, Mean Loss: 2598499.055556, Median Loss 678553.031250, Min Loss: 436803.343750
# Fine-tune epoch 120, Mean Loss: 2744289.112132, Median Loss 713968.000000, Min Loss: 436020.125000
# Fine-tune epoch 130, Mean Loss: 897230.805147, Median Loss 562218.937500, Min Loss: 435293.250000
# Fine-tune epoch 140, Mean Loss: 837196.773897, Median Loss 465905.875000, Min Loss: 428603.718750
# Fine-tune epoch 150, Mean Loss: 838559.292279, Median Loss 461961.843750, Min Loss: 388897.625000
# Fine-tune epoch 160, Mean Loss: 870309.123162, Median Loss 459074.531250, Min Loss: 400351.562500
# Fine-tune epoch 170, Mean Loss: 901294.876838, Median Loss 456425.562500, Min Loss: 380160.718750
# Fine-tune epoch 180, Mean Loss: 884253.795956, Median Loss 451601.656250, Min Loss: 382220.531250
# Fine-tune epoch 190, Mean Loss: 864066.670956, Median Loss 450848.062500, Min Loss: 378529.218750
# Fine-tune epoch 200, Mean Loss: 890815.871324, Median Loss 450239.000000, Min Loss: 370384.531250
# Fine-tune epoch 210, Mean Loss: 863857.659926, Median Loss 449716.656250, Min Loss: 369719.031250
# Fine-tune epoch 220, Mean Loss: 861817.270221, Median Loss 449223.125000, Min Loss: 371769.312500
# Fine-tune epoch 230, Mean Loss: 853785.001838, Median Loss 448761.843750, Min Loss: 365698.625000
# Fine-tune epoch 240, Mean Loss: 825655.308824, Median Loss 448360.406250, Min Loss: 365250.500000
# Fine-tune epoch 250, Mean Loss: 887723.167279, Median Loss 447988.812500, Min Loss: 363177.062500
# Fine-tune epoch 260, Mean Loss: 845390.634191, Median Loss 447659.906250, Min Loss: 360275.125000
# Fine-tune epoch 270, Mean Loss: 825703.474265, Median Loss 447309.812500, Min Loss: 359317.312500
# Fine-tune epoch 280, Mean Loss: 845454.974265, Median Loss 446883.937500, Min Loss: 362127.718750
# Fine-tune epoch 290, Mean Loss: 887423.694853, Median Loss 446876.656250, Min Loss: 417696.781250

# %%
fine_inds_long = np.argsort(fine_best_losses_long)
fig, axs = plt.subplots(2,5, figsize = (20,6))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle("Best fine-tuned models for longer period", fontsize=16)
for i in range(2):
    for j in range(5):
        model = jax.tree_util.tree_map(lambda x: x[fine_inds_long[i*5+j]], fine_best_models_long)
        opt_inv_params = inv_transform_params(model.channel_params_normal)

        # Rebuild the simulator with new cell
        cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])

        cell.delete_stimuli()
        cell.delete_recordings()

        current = jx.step_current(50, 1000, i_amp, dt, t_max_long)
        current = current[cut:]

        cell.stimulate(current, verbose = False)
        cell.record(verbose = False)
        # cell.soma.branch(0).comp(0).stimulate(current, verbose = False)
        # cell.soma.branch(0).comp(0).record(verbose = False)
        cell.set("v", all_setup['v_init'])
        cell.init_states()
        
        initial_state, step_fn, current, time_vec = setup_simulator_step(cell, cut, t_max_long, all_setup["v_init"], i_amp, params = opt_inv_params)

        # Run simulation
        final_preds, final_additional_currents, final_us, final_nn_reses = simulate_full_trace(
            model.spike_neural_net, model.spike_readout_net, model.nospike_neural_net, model.nospike_readout_net, initial_state, step_fn, current, time_vec, u_init, v_data_long.squeeze(), added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr
        )
        axs[i,j].plot(time_vec, v_data_long[0], label="Experimental target", linewidth=2)
        axs[i,j].plot(time_vec, final_preds, label="Single-compartment prediction", linestyle="--", linewidth=2)
        axs[i,j].set_title(f"Model {fine_inds_long[fine_inds_long[i*5+j]]}, Loss: {fine_best_losses_long[fine_inds_long[i*5+j]]:.4f}", fontsize = 10)
        axs[i,j].set_ylim(-100, 60)

# %%
idx = 0

cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])
cell.delete_stimuli()
cell.delete_recordings()

current = jx.step_current(50, 1000, i_amp, dt, t_max_long)
current = current[cut:]

cell.stimulate(current)
cell.record()
cell.set("v", all_setup['v_init'])
cell.init_states()

model = jax.tree_util.tree_map(lambda x: x[fine_inds_long[idx]], fine_best_models_long)
opt_inv_params = inv_transform_params(model.channel_params_normal)

# Rebuild the simulator with new cell
initial_state, step_fn, current, time_vec = setup_simulator_step(cell, cut, t_max_long, all_setup["v_init"], i_amp, params = opt_inv_params)

# Run simulation
final_preds, final_additional_currents, final_us, final_nn_reses = simulate_full_trace(
    model.spike_neural_net, model.spike_readout_net, model.nospike_neural_net, model.nospike_readout_net, initial_state, step_fn, current, time_vec, u_init, v_data_long.squeeze(), added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr
)

loss = fine_simulation_loss_fn(model)


plt.plot(v_data_long[0], label="Data target", linewidth=2)
plt.plot(final_preds, label="Single-compartment prediction", linestyle="--", linewidth=2)
plt.title(f"Best model after fine-tuning, Loss: {loss:.4f}")
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
plt.legend(["Target", "Prediction"])
# Out:
# Added 1 external_states. See `.externals` for details.
# Added 1 recordings. See `.recordings` for details.

# %%
fig, axs = plt.subplots(1,3, figsize = (15,3))
axs[0].plot(time_vec, final_us)
axs[0].set_title("Hidden state (u)")
axs[1].plot(time_vec, final_nn_reses)
axs[1].set_title("Dynamics network output (neural_net)")
axs[2].plot(time_vec, final_additional_currents)
axs[2].set_title("Additional current")
# Out:
# Text(0.5, 1.0, 'Additional current')

# %%
names, lower, upper = get_bounds()

opt_inv_params_list = []
for i in range(10):
    model = jax.tree_util.tree_map(lambda x: x[fine_inds_long[i]], fine_best_models_long)
    opt_inv_params = inv_transform_params(model.channel_params_normal)
    opt_inv_params_list.append(opt_inv_params)

param_matrix = np.stack(opt_inv_params_list)

normalized_params = (param_matrix - lower) / (upper - lower)
normalized_params = np.clip(normalized_params, 0, 1)

fig, ax = plt.subplots(figsize=(9, 6))
indices = np.arange(len(opt_inv_params))

# Draw the [0, 1] range
ax.hlines(indices, 0, 1, color='lightgray', linewidth=5, zorder=1)
colors = plt.cm.tab10(np.linspace(0, 1, 10))
colors = plt.cm.Pastel1(np.linspace(0, 1, 10))
colors = plt.cm.viridis(np.linspace(0.0, 1.0, 10))
sizes = np.linspace(100, 30, 10)
alphas = np.linspace(1.0, 0.5, 10)


# Plot all models
for j in range(10):
    ax.scatter(normalized_params[j], indices, color=colors[j], s=sizes[j], alpha = alphas[j], label=f'Model {j+1}', zorder=2)

# Annotate only the best model (j == 0)
for k in range(len(names)):
    x = normalized_params[0, k]
    y = k
    val = param_matrix[0, k]
    ax.text(x - 0.03, y + 0.4, f"{val:.3f}", fontsize=8, color='k', va='center')


ax.set_yticks(indices)
ax.set_yticklabels(names)
ax.set_xlim(-0.05, 1.05)
ax.set_xlabel("Normalized parameter value")
ax.set_title("Normalized Optimized Parameters from 10 Best Models")
ax.grid(True, axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# Number of parameters: 15

# %% [markdown]
# **Let's learn the difference between our best model and the true data with the NN - but it doesn't say much because in true training time the voltage is not fixed, but dependent on u. Also, we should rather think about the difference of this.**

# %%
idx = 0


cell = build_cell(all_setup['capacitance'], all_setup["eleak"], all_setup['gleak'], all_setup['length'])
cell.delete_stimuli()
cell.delete_recordings()


current = jx.step_current(50, 1000, i_amp, dt, t_max)
current = current[cut:]

cell.stimulate(current)
cell.record()
cell.set("v", all_setup['v_init'])
cell.init_states()

model = jax.tree_util.tree_map(lambda x: x[fine_inds[idx]], fine_best_models)
opt_inv_params = inv_transform_params(model.channel_params_normal)

# Rebuild the simulator with new cell
initial_state, step_fn, current, time_vec = setup_simulator_step(cell, cut, t_max, all_setup["v_init"], i_amp, params = opt_inv_params)

# Run simulation
final_preds, final_additional_currents, final_us, final_nn_reses = simulate_full_trace(
    model.spike_neural_net, model.spike_readout_net, model.nospike_neural_net, model.nospike_readout_net, initial_state, step_fn, current, time_vec, u_init, v_data.squeeze(), added_curr_std, nospike_u_time_constant, spike_u_time_constant, thr
)

loss = simulation_loss_fn(model)

fig, axs = plt.subplots(1,2, figsize = (15,5))
axs[0].plot(v_data[0]-final_preds)
axs[0].set_title("Difference between target and best prediction")
axs[1].plot(np.cumsum(jnp.abs(v_data[0]-final_preds)))
axs[1].set_title("Cumulative absolute difference between target and best prediction")
pickle.dump((final_preds, v_data[0]-final_preds), open("../results/diffs.pkl", "wb"))
# Out:
# Added 1 external_states. See `.externals` for details.
# Added 1 recordings. See `.recordings` for details.

# %%
# Defining a new NN without the channel parameters
class ResidualNeuralNet(eqx.Module):
    linear1: eqx.nn.Linear
    linear2: eqx.nn.Linear
    linear3: eqx.nn.Linear

    def __init__(self, *, key, u_dimension=8, W_matrices: List[jax.Array], epsilon: float = 1e-4):
        k1, k2, k3, k_b1, k_b2, k_b3 = jr.split(key, 6)

        self.linear1 = eqx.nn.Linear(u_dimension + 1, 32, key=k1)
        self.linear2 = eqx.nn.Linear(32, 16, key=k2)
        self.linear3 = eqx.nn.Linear(16, u_dimension, key=k3)

        # Manually override weights and biases
        self.linear1 = eqx.tree_at(lambda l: l.weight, self.linear1, W_matrices[0])
        self.linear2 = eqx.tree_at(lambda l: l.weight, self.linear2, W_matrices[1])
        self.linear3 = eqx.tree_at(lambda l: l.weight, self.linear3, W_matrices[2])

        self.linear1 = eqx.tree_at(
            lambda l: l.bias, self.linear1,
            jr.uniform(k_b1, (32,), minval=-epsilon, maxval=epsilon)
        )
        self.linear2 = eqx.tree_at(
            lambda l: l.bias, self.linear2,
            jr.uniform(k_b2, (16,), minval=-epsilon, maxval=epsilon)
        )
        self.linear3 = eqx.tree_at(
            lambda l: l.bias, self.linear3,
            jr.uniform(k_b3, (u_dimension,), minval=-epsilon, maxval=epsilon)
        )

    def __call__(self, x):
        x = jax.nn.relu(self.linear1(x))
        x = jax.nn.relu(self.linear2(x))
        return self.linear3(x)


class ResidualReadoutNet(eqx.Module):
    linear1: eqx.nn.Linear
    linear2: eqx.nn.Linear

    def __init__(self, *, key, u_dimension=8):
        k1, k2 = jr.split(key, 2)
        self.linear1 = eqx.nn.Linear(u_dimension, 32, key=k1)
        self.linear2 = eqx.nn.Linear(32, 1, key=k2)

    def __call__(self, u):
        x = jax.nn.relu(self.linear1(u))
        return self.linear2(x)


class ResidualCorrectionModel(eqx.Module):
    residual_neural_net: SimpleNeuralNet
    residual_readout_net: ReadoutNet

    def __init__(self, *, key, u_dimension=8, W_matrices: List[jax.Array], epsilon: float = 1e-4):
        k1, k2 = jr.split(key, 2)
        self.residual_neural_net = ResidualNeuralNet(key=k1, u_dimension=u_dimension, W_matrices=W_matrices, epsilon=epsilon)
        self.residual_readout_net = ResidualReadoutNet(key=k2, u_dimension=u_dimension)

    def __call__(self, x):
        u_new = self.residual_neural_net(x)
        return self.residual_readout_net(u_new)

# %%
def residual_simulation(model, voltages, u_init):
    def cond_fn(carry):
        t, _, _ = carry
        return t < len(voltages)

    def body_fn(carry):
        t, u, buffers = carry

        voltage = voltages[t]
        voltage_normalized = normalize_voltage(voltage)
        inputs = jnp.concatenate([u, jnp.expand_dims(voltage_normalized, 0)], axis=0)
        u_new = u + dt*model.residual_neural_net(inputs) / spike_u_time_constant
        residual_pred = model.residual_readout_net(u_new).squeeze()

   

        new_us, new_residual_preds = buffers
        new_residual_preds = new_residual_preds.at[t].set(residual_pred)
        new_us = new_us.at[t].set(u_new)

        return (t + 1, u_new.squeeze(), (new_us, new_residual_preds))

    # Initialize buffers
    residual_preds = jnp.full((len(voltages),), jnp.nan)
    us = jnp.full((len(voltages), u_init.shape[0]), jnp.nan)

    carry = (0, u_init.squeeze(), (us, residual_preds))

    final_carry = eqx.internal.while_loop(
        cond_fun=cond_fn,
        body_fun=body_fn,
        init_val=carry,
        max_steps=len(voltages),
        kind="bounded"
    )

    _, _, (us, residual_preds,)= final_carry

    return us, residual_preds

# %%
def residual_loss(model, voltages, residuals, u_init):
    us, residual_preds = residual_simulation(model, voltages, u_init)
    sse_loss = jnp.sum(jnp.nan_to_num((residual_preds - residuals) ** 2, nan=0.0))
    return sse_loss

# %%
voltages, residuals = pickle.load(open("../results/diffs.pkl", "rb"))

nr_epochs = 1500
key = jr.PRNGKey(42)
model = ResidualCorrectionModel(key=key, u_dimension=u_dimension, W_matrices=W_matrices, epsilon=epsilon)

res_lr = 5e-3
decay_start = 1000
decay_end = 1100

log_uniform_samples = jax.random.uniform(key, shape=(u_dimension,), minval=np.log(0.1), maxval=np.log(10.0))
u_time_constant = jnp.exp(log_uniform_samples)

res_schedule = optax.exponential_decay(
    init_value=res_lr,
    transition_steps=1,
    decay_rate=0.99, # 0.99
    staircase=True,
)

def res_custom_schedule(step):
    # Epochs before decay_start → constant
    lr = res_lr

    # Epochs between decay_start and decay_end → decay
    decay_steps = jnp.clip(step - decay_start, 0, decay_end - decay_start)
    lr = jnp.where(
        step < decay_start,
        res_lr,
        res_schedule(decay_steps)
    )

    # After decay_end → freeze at last decayed value
    final_lr = res_schedule(decay_end - decay_start)
    lr = jnp.where(step > decay_end, final_lr, lr)

    return lr

optimizer = optax.adam(res_custom_schedule)
optimizer_state = optimizer.init(eqx.filter(model, eqx.is_inexact_array))

residual_grad_fn = nnx.jit(nnx.value_and_grad(residual_loss, argnums=0))


for epoch in range(nr_epochs):
    loss, grads = residual_grad_fn(model, voltages, residuals, u_init)
    update, optimizer_state = optimizer.update(grads, optimizer_state, models)
    model = eqx.apply_updates(model, update)
    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss}")
# Out:
# Epoch 0, Loss: 5822.3505859375
# Epoch 10, Loss: 4991.03466796875
# Epoch 20, Loss: 4346.3193359375
# Epoch 30, Loss: 3913.544921875
# Epoch 40, Loss: 3754.185546875
# Epoch 50, Loss: 4608.189453125
# Epoch 60, Loss: 4571.83447265625
# Epoch 70, Loss: 4520.72705078125
# Epoch 80, Loss: 4400.880859375
# Epoch 90, Loss: 4129.87255859375
# Epoch 100, Loss: 3713.326904296875
# Epoch 110, Loss: 3633.962158203125
# Epoch 120, Loss: 3637.833984375
# Epoch 130, Loss: 3585.904052734375
# Epoch 140, Loss: 3537.160400390625
# Epoch 150, Loss: 3472.4638671875
# Epoch 160, Loss: 3451.546142578125
# Epoch 170, Loss: 3438.690185546875
# Epoch 180, Loss: 3433.25146484375
# Epoch 190, Loss: 3664.65380859375
# Epoch 200, Loss: 3487.572021484375
# Epoch 210, Loss: 3436.84765625
# Epoch 220, Loss: 3415.249267578125
# Epoch 230, Loss: 3407.907958984375
# Epoch 240, Loss: 3403.015380859375
# Epoch 250, Loss: 3398.506591796875
# Epoch 260, Loss: 3394.204833984375
# Epoch 270, Loss: 3446.649658203125
# Epoch 280, Loss: 3415.810791015625
# Epoch 290, Loss: 3388.538818359375
# Epoch 300, Loss: 3384.24267578125
# Epoch 310, Loss: 3372.69970703125
# Epoch 320, Loss: 3599.469482421875
# Epoch 330, Loss: 3371.534423828125
# Epoch 340, Loss: 3382.1025390625
# Epoch 350, Loss: 3355.928955078125
# Epoch 360, Loss: 3357.6982421875
# Epoch 370, Loss: 3749.8232421875
# Epoch 380, Loss: 3493.33251953125
# Epoch 390, Loss: 3376.644775390625
# Epoch 400, Loss: 3369.648193359375
# Epoch 410, Loss: 3351.039306640625
# Epoch 420, Loss: 3331.781982421875
# Epoch 430, Loss: 3321.11767578125
# Epoch 440, Loss: 3307.318115234375
# Epoch 450, Loss: 3309.427490234375
# Epoch 460, Loss: 3327.90966796875
# Epoch 470, Loss: 3294.087646484375
# Epoch 480, Loss: 3802.941650390625
# Epoch 490, Loss: 3949.979736328125
# Epoch 500, Loss: 3473.516357421875
# Epoch 510, Loss: 3385.92529296875
# Epoch 520, Loss: 3328.02197265625
# Epoch 530, Loss: 3295.754638671875
# Epoch 540, Loss: 3273.8359375
# Epoch 550, Loss: 3252.943603515625
# Epoch 560, Loss: 3235.959716796875
# Epoch 570, Loss: 3219.086181640625
# Epoch 580, Loss: 3205.4912109375
# Epoch 590, Loss: 3261.5556640625
# Epoch 600, Loss: 3322.903076171875
# Epoch 610, Loss: 3370.528564453125
# Epoch 620, Loss: 3424.530029296875
# Epoch 630, Loss: 3252.699462890625
# Epoch 640, Loss: 3267.44287109375
# Epoch 650, Loss: 3366.925537109375
# Epoch 660, Loss: 4026.86083984375
# Epoch 670, Loss: 3463.302978515625
# Epoch 680, Loss: 3358.1396484375
# Epoch 690, Loss: 3301.5966796875
# Epoch 700, Loss: 3245.274658203125
# Epoch 710, Loss: 3214.47509765625
# Epoch 720, Loss: 3193.39306640625
# Epoch 730, Loss: 3175.8173828125
# Epoch 740, Loss: 3157.50927734375
# Epoch 750, Loss: 3802.612548828125
# Epoch 760, Loss: 3761.789306640625
# Epoch 770, Loss: 3590.57080078125
# Epoch 780, Loss: 3460.60693359375
# Epoch 790, Loss: 3445.83154296875
# Epoch 800, Loss: 3422.041259765625
# Epoch 810, Loss: 3412.64990234375
# Epoch 820, Loss: 3406.33154296875
# Epoch 830, Loss: 3401.556396484375
# Epoch 840, Loss: 3396.277587890625
# Epoch 850, Loss: 3388.01953125
# Epoch 860, Loss: 3374.74267578125
# Epoch 870, Loss: 3364.433837890625
# Epoch 880, Loss: 3357.369873046875
# Epoch 890, Loss: 3348.867919921875
# Epoch 900, Loss: 3339.36181640625
# Epoch 910, Loss: 3328.497314453125
# Epoch 920, Loss: 3316.2294921875
# Epoch 930, Loss: 3301.983642578125
# Epoch 940, Loss: 3285.005615234375
# Epoch 950, Loss: 3463.184814453125
# Epoch 960, Loss: 4239.98291015625
# Epoch 970, Loss: 3720.451904296875
# Epoch 980, Loss: 3391.011962890625
# Epoch 990, Loss: 3295.008544921875
# Epoch 1000, Loss: 3205.3818359375
# Epoch 1010, Loss: 3128.09716796875
# Epoch 1020, Loss: 3070.985595703125
# Epoch 1030, Loss: 3020.783447265625
# Epoch 1040, Loss: 2965.982177734375
# Epoch 1050, Loss: 2904.8076171875
# Epoch 1060, Loss: 2834.066650390625
# Epoch 1070, Loss: 2751.188720703125
# Epoch 1080, Loss: 4220.890625
# Epoch 1090, Loss: 3287.800048828125
# Epoch 1100, Loss: 3113.78515625
# Epoch 1110, Loss: 2906.0185546875
# Epoch 1120, Loss: 2806.20263671875
# Epoch 1130, Loss: 2728.733154296875
# Epoch 1140, Loss: 2645.272216796875
# Epoch 1150, Loss: 2600.82861328125
# Epoch 1160, Loss: 2573.751953125
# Epoch 1170, Loss: 2498.40771484375
# Epoch 1180, Loss: 2659.14208984375
# Epoch 1190, Loss: 5480.66357421875
# Epoch 1200, Loss: 3994.158203125
# Epoch 1210, Loss: 3654.771240234375
# Epoch 1220, Loss: 3519.921630859375
# Epoch 1230, Loss: 3460.530517578125
# Epoch 1240, Loss: 3433.40478515625
# Epoch 1250, Loss: 3398.368896484375
# Epoch 1260, Loss: 3349.581298828125
# Epoch 1270, Loss: 3287.153076171875
# Epoch 1280, Loss: 3226.176025390625
# Epoch 1290, Loss: 3175.43994140625
# Epoch 1300, Loss: 3132.043212890625
# Epoch 1310, Loss: 3098.08349609375
# Epoch 1320, Loss: 3069.722900390625
# Epoch 1330, Loss: 3043.499267578125
# Epoch 1340, Loss: 3015.46337890625
# Epoch 1350, Loss: 2986.960205078125
# Epoch 1360, Loss: 2958.839111328125
# Epoch 1370, Loss: 2926.10986328125
# Epoch 1380, Loss: 2885.458984375
# Epoch 1390, Loss: 2842.48779296875
# Epoch 1400, Loss: 2796.87744140625
# Epoch 1410, Loss: 2746.326904296875
# Epoch 1420, Loss: 2687.77392578125
# Epoch 1430, Loss: 2626.484619140625
# Epoch 1440, Loss: 2579.8798828125
# Epoch 1450, Loss: 2530.693359375
# Epoch 1460, Loss: 2720.0576171875
# Epoch 1470, Loss: 2526.498779296875
# Epoch 1480, Loss: 2495.797119140625
# Epoch 1490, Loss: 2449.317626953125

# %%
final_us, final_residual_preds = residual_simulation(model, voltages, u_init)
plt.figure(figsize=(12, 6))
plt.plot(residuals, label="Residuals (target)", linewidth=1.5)
plt.plot(final_residual_preds, label="Residuals (prediction)", linestyle="--", linewidth=2)
plt.legend()

sse_loss = jnp.sum((final_residual_preds - residuals) ** 2)
print(f"Final SSE Loss: {sse_loss:.4f}")
# Out:
# Final SSE Loss: 2399.9958

# %% [markdown]
# With good lr, it can fit the difference almost perfectly.
